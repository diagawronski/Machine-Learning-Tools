# %% [markdown]
# # 0.) Import and Clean data

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Econ 441B/Country-data.csv", sep = ",")

# %%
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
df.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
names = df[["country"]]
X = df.drop(["country"], axis = 1)

# %%
scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %% [markdown]
# # 1.) Fit a kmeans Model with any Number of Clusters

# %%
kmeans = KMeans(n_clusters= 5, random_state=42).fit(X_scaled)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # 2.) Pick two features to visualize across

# %%
X.columns
# Out:
# Index(['child_mort', 'exports', 'health', 'imports', 'income', 'inflation',
#        'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
# CHANGE THESE BASED ON WHICH IS INTERESTING TO YOU
# income and life expectancy
x1_index = 4
x2_index = 6


plt.scatter(X_scaled[:, x1_index], X_scaled[:, x2_index], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, x1_index], kmeans.cluster_centers_[:, x2_index], marker='o', color='black', s=100)

plt.xlabel(X.columns[x1_index])
plt.ylabel(X.columns[x2_index])
plt.title('Scatter Plot of Customers')
plt.legend(["Group 1", "Center", "Group 2"])
plt.grid()
plt.show()

# %% [markdown]
# # 3.) Check a range of k-clusters and visualize to find the elbow. Test 30 different random starting places for the centroid means

# %%
wcss = [] 

for k in range(1, 10): 
    kmeans = KMeans(n_clusters=k, n_init=30, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)


plt.plot(range(1, 10), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# # 4.) Use the above work and economic critical thinking to choose a number of clusters. Explain why you chose the number of clusters and fit a model accordingly.

# %%
kmeans = KMeans(n_clusters= 2, random_state=42).fit(X_scaled)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# *I chose k=2 because, using the elbow method, we see that the WCSS decreases less steeply around k=2. This means that the model complexity beyond k=2 would not help the accuracy as much.*

# %% [markdown]
# # 5.) Create a list of the countries that are in each cluster. Write interesting things you notice. Hint : Use .predict(method)

# %%
preds = pd.DataFrame(kmeans.predict(X_scaled))
preds.columns = ["Cluster"]

# %%
output = pd.concat([preds, names], axis = 1)
output.head()
# Out:
#    Cluster              country
# 0        1          Afghanistan
# 1        0              Albania
# 2        0              Algeria
# 3        1               Angola
# 4        0  Antigua and Barbuda

# %%
cluster_1 = output.loc[output['Cluster'] == 0, 'country'].tolist()
cluster_2 = output.loc[output['Cluster'] == 1, 'country'].tolist()

# %%
print("Cluster 1:")
cluster_1
# Out:
# Cluster 1:
# ['Albania',
#  'Algeria',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Bhutan',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Canada',
#  'Cape Verde',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Estonia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Grenada',
#  'Hungary',
#  'Iceland',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kuwait',
#  'Latvia',
#  'Lebanon',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Macedonia, FYR',
#  'Malaysia',
#  'Maldives',
#  'Malta',
#  'Mauritius',
#  'Moldova',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
# ...

# %%
print("Cluster 2:")
cluster_2
# Out:
# Cluster 2:
# ['Afghanistan',
#  'Angola',
#  'Bangladesh',
#  'Benin',
#  'Bolivia',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  "Cote d'Ivoire",
#  'Egypt',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Gabon',
#  'Gambia',
#  'Ghana',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'India',
#  'Indonesia',
#  'Iraq',
#  'Kenya',
#  'Kiribati',
#  'Kyrgyz Republic',
#  'Lao',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Micronesia, Fed. Sts.',
#  'Mongolia',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Niger',
#  'Nigeria',
#  'Pakistan',
#  'Philippines',
#  'Rwanda',
#  'Samoa',
#  'Senegal',
#  'Sierra Leone',
#  'Solomon Islands',
#  'South Africa',
#  'Sudan',
#  'Tajikistan',
#  'Tanzania',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Turkmenistan',
# ...

# %% [markdown]
# *As seen above, the clusters separate countries into two groups of different economic development. Cluster 1 includes many well-developed countries, such as the US, UK, Singapore, and Germany. Cluster 2 has less-developed countries, such as the Solomon Islands, Bangladesh, and Nepal.*

# %% [markdown]
# #6.) Create a table of Descriptive Statistics. Rows being the Cluster number and columns being all the features. Values being the mean of the centroid. Use the nonscaled X values for interprotation

# %%
cluster_df = pd.concat([preds, X], axis =1)

# %%
cluster_df.groupby("Cluster").mean()
# Out:
#          child_mort    exports    health    imports        income  inflation  \
# Cluster
# 0         12.161616  48.603030  7.314040  49.121212  26017.171717   5.503545
# 1         76.280882  30.198515  6.090147  43.642146   4227.397059  11.098750
#
#          life_expec  total_fer          gdpp
# Cluster
# 0         76.493939   1.941111  20507.979798
# 1         61.910294   4.413824   1981.235294

# %%
cluster_df.groupby('Cluster').median()
# Out:
#          child_mort  exports  health  imports   income  inflation  life_expec  \
# Cluster
# 0              10.3    40.10    7.04     46.2  19400.0       3.53        76.4
# 1              65.6    24.95    5.34     41.5   2590.0       8.21        62.0
#
#          total_fer     gdpp
# Cluster
# 0             1.88  11900.0
# 1             4.58   1155.0

# %%
cluster_df.groupby("Cluster").std()
# Out:
#          child_mort    exports    health    imports        income  inflation  \
# Cluster
# 0          8.523122  30.116032  2.716652  26.928785  20441.749847   6.957187
# 1         38.076068  18.201742  2.645319  19.323451   4890.581414  13.682630
#
#          life_expec  total_fer          gdpp
# Cluster
# 0          3.735757   0.486744  20578.727127
# 1          6.897418   1.285590   2528.509189

# %% [markdown]
# # Q7.) Write an observation about the descriptive statistics.

# %% [markdown]
# *CLuster 1, which includes the well-developed countries, has lower child mortality rates, inflation, and total fertility than Cluster 2 on average. It has higher exports, imports, income, health, life expectancy, and GDPP than Cluster 2 on average.*
#
# *These results are expected based on the differences we observed between the two clusters.*
